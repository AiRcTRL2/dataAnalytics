# %% [markdown]
# # Data Quality Report

# %%
#Import package pandas for data analysis
import pandas as pd

# Import package numpy for numeric computing
import numpy as np

# Import package matplotlib for visualisation/plotting
import matplotlib.pyplot as plt

# Import PdfPages to handle creating PDFs later
from matplotlib.backends.backend_pdf import PdfPages

# %%
# Reading credit data from a csv file, into a data frame
ctData = pd.read_csv('CreditRisk-18206646.csv')
# Show data frame for first few rows to ensure everything is working correctly. 
ctData.head()
# Out:
#   RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 0             Bad                    83                    176
# 1             Bad                    64                     25
# 2             Bad                    73                    229
# 3            Good                    68                    272
# 4             Bad                    68                    147
#
#    MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 0                          8              70                      8
# 1                          1               9                      5
# 2                         13             122                     16
# 3                          4              89                     31
# 4                          5              76                     30
#
#    NumTrades60Ever2DerogPubRec  NumTrades90Ever2DerogPubRec  \
# 0                            0                            0
# 1                            1                            1
# 2                            0                            0
# 3                            0                            0
# 4                            2                            0
#
#    PercentTradesNeverDelq  MSinceMostRecentDelq  ...  PercentInstallTrades  \
# 0                     100                    -7  ...                    50
# 1                     100                    -7  ...                    17
# 2                      88                     3  ...                    41
# 3                     100                    -7  ...                    27
# 4                      72                    40  ...                    22
#
#    MSinceMostRecentInqexcl7days  NumInqLast6M  NumInqLast6Mexcl7days  \
# 0                             0             0                      0
# 1                             0             1                      1
# 2                             0             0                      0
# 3                             0             0                      0
# 4                             1             3                      3
#
#    NetFractionRevolvingBurden  NetFractionInstallBurden  \
# 0                          38                        91
# 1                           8                        -8
# 2                          40                        56
# 3                          90                        90
# 4                          48                        61
#
#    NumRevolvingTradesWBalance  NumInstallTradesWBalance  \
# 0                           2                         2
# 1                           2                         1
# 2                           2                         2
# 3                           8                         4
# 4                           4                         2
#
#    NumBank2NatlTradesWHighUtilization  PercentTradesWBalance
# 0                                   0                     80
# 1                                   0                     75
# 2                                   0                    100
# 3                                   4                     86
# 4                                   1                     67
#
# [5 rows x 24 columns]

# %%
# Use .shape to find how many (rows,columns) exist in the data
ctData.shape
# Out:
# (1000, 24)

# %%
# Show the first five rows
ctData[:5]
# Out:
#   RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 0             Bad                    83                    176
# 1             Bad                    64                     25
# 2             Bad                    73                    229
# 3            Good                    68                    272
# 4             Bad                    68                    147
#
#    MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 0                          8              70                      8
# 1                          1               9                      5
# 2                         13             122                     16
# 3                          4              89                     31
# 4                          5              76                     30
#
#    NumTrades60Ever2DerogPubRec  NumTrades90Ever2DerogPubRec  \
# 0                            0                            0
# 1                            1                            1
# 2                            0                            0
# 3                            0                            0
# 4                            2                            0
#
#    PercentTradesNeverDelq  MSinceMostRecentDelq  ...  PercentInstallTrades  \
# 0                     100                    -7  ...                    50
# 1                     100                    -7  ...                    17
# 2                      88                     3  ...                    41
# 3                     100                    -7  ...                    27
# 4                      72                    40  ...                    22
#
#    MSinceMostRecentInqexcl7days  NumInqLast6M  NumInqLast6Mexcl7days  \
# 0                             0             0                      0
# 1                             0             1                      1
# 2                             0             0                      0
# 3                             0             0                      0
# 4                             1             3                      3
#
#    NetFractionRevolvingBurden  NetFractionInstallBurden  \
# 0                          38                        91
# 1                           8                        -8
# 2                          40                        56
# 3                          90                        90
# 4                          48                        61
#
#    NumRevolvingTradesWBalance  NumInstallTradesWBalance  \
# 0                           2                         2
# 1                           2                         1
# 2                           2                         2
# 3                           8                         4
# 4                           4                         2
#
#    NumBank2NatlTradesWHighUtilization  PercentTradesWBalance
# 0                                   0                     80
# 1                                   0                     75
# 2                                   0                    100
# 3                                   4                     86
# 4                                   1                     67
#
# [5 rows x 24 columns]

# %%
# Show the last 5 rows
ctData[-5:]
# Out:
#     RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 995            Good                    75                    254
# 996            Good                    66                    131
# 997            Good                    83                     97
# 998            Good                    -9                     -9
# 999            Good                    56                    368
#
#      MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 995                          4              60                      9
# 996                         13              83                      4
# 997                          7              57                     17
# 998                         -9              -9                     -9
# 999                         10              44                     25
#
#      NumTrades60Ever2DerogPubRec  NumTrades90Ever2DerogPubRec  \
# 995                            0                            0
# 996                            4                            4
# 997                            0                            0
# 998                           -9                           -9
# 999                            0                            0
#
#      PercentTradesNeverDelq  MSinceMostRecentDelq  ...  PercentInstallTrades  \
# 995                     100                    -7  ...                    44
# 996                      67                    67  ...                    33
# 997                     100                    -7  ...                    24
# 998                      -9                    -9  ...                    -9
# 999                      92                     4  ...                    16
#
#      MSinceMostRecentInqexcl7days  NumInqLast6M  NumInqLast6Mexcl7days  \
# 995                             0             1                      1
# 996                            -7             0                      0
# 997                            -7             0                      0
# 998                            -9            -9                     -9
# 999                             9             0                      0
#
#      NetFractionRevolvingBurden  NetFractionInstallBurden  \
# 995                          60                        95
# 996                          67                        -8
# 997                          19                        85
# 998                          -9                        -9
# 999                          41                        74
#
#      NumRevolvingTradesWBalance  NumInstallTradesWBalance  \
# 995                           2                         2
# 996                           2                         1
# 997                           3                         3
# 998                          -9                        -9
# 999                          10                         3
#
#      NumBank2NatlTradesWHighUtilization  PercentTradesWBalance
# 995                                   0                     80
# 996                                   0                    100
# 997                                   0                     60
# 998                                  -9                     -9
# 999                                   2                     65
#
# [5 rows x 24 columns]

# %%
continuousCols = ["ExternalRiskEstimate",\
                  "PercentTradesNeverDelq",\
                  "PercentInstallTrades",\
                  "NetFractionRevolvingBurden",\
                  "NetFractionInstallBurden",\
                  "NumRevolvingTradesWBalance",\
                  "NumInstallTradesWBalance",\
                  "Num2Bank2NatlTradesWHighUtilization",\
                  "PercentTradesWBalance",\
                  "MSinceOldestTradeOpen",\
                  "MSinceMostRecentTradeOpen",\
                  "AverageMInFile",\
                  "NumSatisfactoryTrades",\
                  "NumTrades60Ever2DerogPubRec",\
                  "NumTrades90Ever2DerogPubRec",\
                  "MSinceMostRecentDelq",\
                  "MaxDelq2PublicRecLast12M",\
                  "MaxDelqEver",\
                  "NumTotalTrades",\
                  "NumTradesOpeninLast12M",\
                  "MaxDelq2PublicRecLast12M",\
                  "NumInqLast6Mexcl7days",\
                  "NumTradesOpeninLast12M",\
                  "MaxDelq2PublicRecLast12M",\
                  "NumInqLast6Mexcl7days"]

# Categorical data in Pandas requires a limited number of possible values. Thus, RiskPerformance unordered 
# categorical data, while MaxDelq2PublicRecLast12M and MaxDelqEver are the only ordered categorical data.
ctData['RiskPerformance'] = ctData['RiskPerformance'].astype("category",copy=False)
ctData['MaxDelq2PublicRecLast12M'] = ctData['MaxDelq2PublicRecLast12M'].astype("category",copy=False)
ctData['MaxDelqEver'] = ctData['MaxDelqEver'].astype("category",copy=False)

# Show that columns have been converted
ctData.dtypes 


## Note for later: Data doesn't have unique IDs?
# Out:
# RiskPerformance                       category
# ExternalRiskEstimate                     int64
# MSinceOldestTradeOpen                    int64
# MSinceMostRecentTradeOpen                int64
# AverageMInFile                           int64
# NumSatisfactoryTrades                    int64
# NumTrades60Ever2DerogPubRec              int64
# NumTrades90Ever2DerogPubRec              int64
# PercentTradesNeverDelq                   int64
# MSinceMostRecentDelq                     int64
# MaxDelq2PublicRecLast12M              category
# MaxDelqEver                           category
# NumTotalTrades                           int64
# NumTradesOpeninLast12M                   int64
# PercentInstallTrades                     int64
# MSinceMostRecentInqexcl7days             int64
# NumInqLast6M                             int64
# NumInqLast6Mexcl7days                    int64
# NetFractionRevolvingBurden               int64
# NetFractionInstallBurden                 int64
# NumRevolvingTradesWBalance               int64
# NumInstallTradesWBalance                 int64
# NumBank2NatlTradesWHighUtilization       int64
# PercentTradesWBalance                    int64
# dtype: object

# %% [markdown]
# #### Identifying duplicate rows

# %%
pd.set_option('display.max_rows', 25)
# Let's use the df.duplicated() function to identify if we have duplicates. ctData.duplicated() would return both 
# True and False rows. So, we define only to return those rows where the data is in fact duplicated.
ctData[ctData.duplicated() == True]
# Out:
#     RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 62              Bad                    -9                     -9
# 102             Bad                    -9                     -9
# 126            Good                    -9                     -9
# 150             Bad                    -9                     -9
# 156             Bad                    -9                     -9
# 186             Bad                    -9                     -9
# 190             Bad                    -9                     -9
# 230            Good                    -9                     -9
# 242            Good                    -9                     -9
# 249            Good                    -9                     -9
# 281            Good                    -9                     -9
# 284             Bad                    -9                     -9
# ..              ...                   ...                    ...
# 753             Bad                    -9                     -9
# 765             Bad                    -9                     -9
# 767            Good                    -9                     -9
# 814            Good                    -9                     -9
# 816             Bad                    -9                     -9
# 843             Bad                    -9                     -9
# 878             Bad                    -9                     -9
# 893             Bad                    -9                     -9
# 903            Good                    -9                     -9
# 904            Good                    -9                     -9
# 981            Good                    -9                     -9
# 998            Good                    -9                     -9
#
#      MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 62                          -9              -9                     -9
# 102                         -9              -9                     -9
# 126                         -9              -9                     -9
# 150                         -9              -9                     -9
# 156                         -9              -9                     -9
# 186                         -9              -9                     -9
# 190                         -9              -9                     -9
# 230                         -9              -9                     -9
# 242                         -9              -9                     -9
# 249                         -9              -9                     -9
# 281                         -9              -9                     -9
# 284                         -9              -9                     -9
# ..                         ...             ...                    ...
# 753                         -9              -9                     -9
# 765                         -9              -9                     -9
# 767                         -9              -9                     -9
# 814                         -9              -9                     -9
# 816                         -9              -9                     -9
# 843                         -9              -9                     -9
# 878                         -9              -9                     -9
# 893                         -9              -9                     -9
# 903                         -9              -9                     -9
# 904                         -9              -9                     -9
# 981                         -9              -9                     -9
# 998                         -9              -9                     -9
#
#      NumTrades60Ever2DerogPubRec  NumTrades90Ever2DerogPubRec  \
# 62                            -9                           -9
# 102                           -9                           -9
# 126                           -9                           -9
# 150                           -9                           -9
# 156                           -9                           -9
# 186                           -9                           -9
# 190                           -9                           -9
# 230                           -9                           -9
# 242                           -9                           -9
# 249                           -9                           -9
# 281                           -9                           -9
# 284                           -9                           -9
# ..                           ...                          ...
# 753                           -9                           -9
# 765                           -9                           -9
# 767                           -9                           -9
# 814                           -9                           -9
# 816                           -9                           -9
# 843                           -9                           -9
# 878                           -9                           -9
# 893                           -9                           -9
# 903                           -9                           -9
# 904                           -9                           -9
# 981                           -9                           -9
# 998                           -9                           -9
#
#      PercentTradesNeverDelq  MSinceMostRecentDelq  ... PercentInstallTrades  \
# 62                       -9                    -9  ...                   -9
# 102                      -9                    -9  ...                   -9
# 126                      -9                    -9  ...                   -9
# 150                      -9                    -9  ...                   -9
# 156                      -9                    -9  ...                   -9
# 186                      -9                    -9  ...                   -9
# 190                      -9                    -9  ...                   -9
# 230                      -9                    -9  ...                   -9
# 242                      -9                    -9  ...                   -9
# 249                      -9                    -9  ...                   -9
# 281                      -9                    -9  ...                   -9
# 284                      -9                    -9  ...                   -9
# ..                      ...                   ...  ...                  ...
# 753                      -9                    -9  ...                   -9
# 765                      -9                    -9  ...                   -9
# 767                      -9                    -9  ...                   -9
# 814                      -9                    -9  ...                   -9
# 816                      -9                    -9  ...                   -9
# 843                      -9                    -9  ...                   -9
# 878                      -9                    -9  ...                   -9
# 893                      -9                    -9  ...                   -9
# 903                      -9                    -9  ...                   -9
# 904                      -9                    -9  ...                   -9
# 981                      -9                    -9  ...                   -9
# 998                      -9                    -9  ...                   -9
#
#     MSinceMostRecentInqexcl7days  NumInqLast6M  NumInqLast6Mexcl7days  \
# 62                            -9            -9                     -9
# 102                           -9            -9                     -9
# 126                           -9            -9                     -9
# 150                           -9            -9                     -9
# 156                           -9            -9                     -9
# 186                           -9            -9                     -9
# 190                           -9            -9                     -9
# 230                           -9            -9                     -9
# 242                           -9            -9                     -9
# 249                           -9            -9                     -9
# 281                           -9            -9                     -9
# 284                           -9            -9                     -9
# ..                           ...           ...                    ...
# 753                           -9            -9                     -9
# 765                           -9            -9                     -9
# 767                           -9            -9                     -9
# 814                           -9            -9                     -9
# 816                           -9            -9                     -9
# 843                           -9            -9                     -9
# 878                           -9            -9                     -9
# 893                           -9            -9                     -9
# 903                           -9            -9                     -9
# 904                           -9            -9                     -9
# 981                           -9            -9                     -9
# 998                           -9            -9                     -9
#
#      NetFractionRevolvingBurden  NetFractionInstallBurden  \
# 62                           -9                        -9
# 102                          -9                        -9
# 126                          -9                        -9
# 150                          -9                        -9
# 156                          -9                        -9
# 186                          -9                        -9
# 190                          -9                        -9
# 230                          -9                        -9
# 242                          -9                        -9
# 249                          -9                        -9
# 281                          -9                        -9
# 284                          -9                        -9
# ..                          ...                       ...
# 753                          -9                        -9
# 765                          -9                        -9
# 767                          -9                        -9
# 814                          -9                        -9
# 816                          -9                        -9
# 843                          -9                        -9
# 878                          -9                        -9
# 893                          -9                        -9
# 903                          -9                        -9
# 904                          -9                        -9
# 981                          -9                        -9
# 998                          -9                        -9
#
#      NumRevolvingTradesWBalance  NumInstallTradesWBalance  \
# 62                           -9                        -9
# 102                          -9                        -9
# 126                          -9                        -9
# 150                          -9                        -9
# 156                          -9                        -9
# 186                          -9                        -9
# 190                          -9                        -9
# 230                          -9                        -9
# 242                          -9                        -9
# 249                          -9                        -9
# 281                          -9                        -9
# 284                          -9                        -9
# ..                          ...                       ...
# 753                          -9                        -9
# 765                          -9                        -9
# 767                          -9                        -9
# 814                          -9                        -9
# 816                          -9                        -9
# 843                          -9                        -9
# 878                          -9                        -9
# 893                          -9                        -9
# 903                          -9                        -9
# 904                          -9                        -9
# 981                          -9                        -9
# 998                          -9                        -9
#
#      NumBank2NatlTradesWHighUtilization  PercentTradesWBalance
# 62                                   -9                     -9
# 102                                  -9                     -9
# 126                                  -9                     -9
# 150                                  -9                     -9
# 156                                  -9                     -9
# 186                                  -9                     -9
# 190                                  -9                     -9
# 230                                  -9                     -9
# 242                                  -9                     -9
# 249                                  -9                     -9
# 281                                  -9                     -9
# 284                                  -9                     -9
# ..                                  ...                    ...
# 753                                  -9                     -9
# 765                                  -9                     -9
# 767                                  -9                     -9
# 814                                  -9                     -9
# 816                                  -9                     -9
# 843                                  -9                     -9
# 878                                  -9                     -9
# 893                                  -9                     -9
# 903                                  -9                     -9
# 904                                  -9                     -9
# 981                                  -9                     -9
# 998                                  -9                     -9
#
# [51 rows x 24 columns]

# %% [markdown]
# #### Now that we have identified that we have 51 duplicated rows, let's drop them.

# %%
# Use the pandas function to drop duplicate rows
ctData.drop_duplicates(inplace=True)
# check again if we have duplicates, and if 0 is returned, we know it worked!
ctData[ctData.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [RiskPerformance, ExternalRiskEstimate, MSinceOldestTradeOpen, MSinceMostRecentTradeOpen, AverageMInFile, NumSatisfactoryTrades, NumTrades60Ever2DerogPubRec, NumTrades90Ever2DerogPubRec, PercentTradesNeverDelq, MSinceMostRecentDelq, MaxDelq2PublicRecLast12M, MaxDelqEver, NumTotalTrades, NumTradesOpeninLast12M, PercentInstallTrades, MSinceMostRecentInqexcl7days, NumInqLast6M, NumInqLast6Mexcl7days, NetFractionRevolvingBurden, NetFractionInstallBurden, NumRevolvingTradesWBalance, NumInstallTradesWBalance, NumBank2NatlTradesWHighUtilization, PercentTradesWBalance]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# #### We can see that the duplicate removal worked, since our DataFrame now has 949 rows left (1000-51 duplicates). The next step is to make sure we have no columns with constant values.

# %%
# Identify the columns along with their count of unique values
print("Column \t|| UniqueValues") 
for column in ctData:
    print(column + "\t|| " + str(len(ctData[column].unique())))
# Out:
# Column 	|| UniqueValues
# RiskPerformance	|| 2
# ExternalRiskEstimate	|| 47
# MSinceOldestTradeOpen	|| 339
# MSinceMostRecentTradeOpen	|| 58
# AverageMInFile	|| 159
# NumSatisfactoryTrades	|| 58
# NumTrades60Ever2DerogPubRec	|| 16
# NumTrades90Ever2DerogPubRec	|| 14
# PercentTradesNeverDelq	|| 52
# MSinceMostRecentDelq	|| 78
# MaxDelq2PublicRecLast12M	|| 10
# MaxDelqEver	|| 8
# NumTotalTrades	|| 62
# NumTradesOpeninLast12M	|| 14
# PercentInstallTrades	|| 78
# MSinceMostRecentInqexcl7days	|| 26
# NumInqLast6M	|| 15
# NumInqLast6Mexcl7days	|| 15
# NetFractionRevolvingBurden	|| 110
# NetFractionInstallBurden	|| 104
# NumRevolvingTradesWBalance	|| 22
# NumInstallTradesWBalance	|| 16
# NumBank2NatlTradesWHighUtilization	|| 15
# PercentTradesWBalance	|| 79

# %% [markdown]
# #### Now that we can see that there are no columns in the dataset that has just 1 unique value, we can continue. Let's save our cleaned CSV.

# %%
# Save updated DataFrame to CSV
ctData.to_csv('cleanedCreditRisk-18206645.csv')

# %% [markdown]
# ## Now we are going to reimport the cleaned CSV and perform some statistical analysis for the data report

# %%
ctDataCleaned = pd.read_csv('cleanedCreditRisk-18206645.csv')
ctDataCleaned.drop('Unnamed: 0',axis=1,inplace=True)
ctCategorical = ['RiskPerformance','MaxDelq2PublicRecLast12M','MaxDelqEver']
# Category data does not save to CSV file correctly, so we must convert it again for our new file.
ctDataCleaned['RiskPerformance'] = ctData['RiskPerformance'].astype("category",copy=False)
ctDataCleaned['MaxDelq2PublicRecLast12M'] = ctData['MaxDelq2PublicRecLast12M'].astype("category",copy=False)
ctDataCleaned['MaxDelqEver'] = ctData['MaxDelqEver'].astype("category",copy=False)

ctDataCleaned.dtypes

## Note: Pandas added an unnamed column as a unique ID column, since it was missing from our original data set.
## It automatically assigned this as an integer, which causes us problems when we calculate statistics.
# Out:
# Unnamed: 0                               int64
# RiskPerformance                       category
# ExternalRiskEstimate                     int64
# MSinceOldestTradeOpen                    int64
# MSinceMostRecentTradeOpen                int64
# AverageMInFile                           int64
# NumSatisfactoryTrades                    int64
# NumTrades60Ever2DerogPubRec              int64
# NumTrades90Ever2DerogPubRec              int64
# PercentTradesNeverDelq                   int64
# MSinceMostRecentDelq                     int64
# MaxDelq2PublicRecLast12M              category
# MaxDelqEver                           category
# NumTotalTrades                           int64
# NumTradesOpeninLast12M                   int64
# PercentInstallTrades                     int64
# MSinceMostRecentInqexcl7days             int64
# NumInqLast6M                             int64
# NumInqLast6Mexcl7days                    int64
# NetFractionRevolvingBurden               int64
# NetFractionInstallBurden                 int64
# NumRevolvingTradesWBalance               int64
# NumInstallTradesWBalance                 int64
# NumBank2NatlTradesWHighUtilization       int64
# PercentTradesWBalance                    int64
# dtype: object

# %%
ctDataCleaned
# Out:
#      Unnamed: 0 RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 0             0             Bad                    83                    176
# 1             1             Bad                    64                     25
# 2             2             Bad                    73                    229
# 3             3            Good                    68                    272
# 4             4             Bad                    68                    147
# 5             5             Bad                    72                    120
# 6             6             Bad                    87                    318
# 7             7             Bad                    62                    295
# 8             8            Good                    -9                     -9
# 9             9             Bad                    61                    105
# 10           10             Bad                    57                     81
# 11           11            Good                    85                    150
# ..          ...             ...                   ...                    ...
# 937         987            Good                    88                    190
# 938         988            Good                    65                    174
# 939         989            Good                    65                    125
# 940         990            Good                    83                    175
# 941         991             Bad                    84                    170
# 942         992             Bad                    57                    164
# 943         993             Bad                    57                    164
# 944         994            Good                    76                    163
# 945         995             Bad                    75                    254
# 946         996            Good                    66                    131
# 947         997             Bad                    83                     97
# 948         999            Good                    56                    368
#
#      MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 0                            8              70                      8
# 1                            1               9                      5
# 2                           13             122                     16
# 3                            4              89                     31
# 4                            5              76                     30
# 5                            3              51                     16
# 6                           31              99                     12
# 7                            7             124                     55
# 8                           -9              -9                     -9
# 9                            8              53                     44
# 10                           2              47                     13
# 11                           7              68                     19
# ..                         ...             ...                    ...
# 937                          6              65                     20
# 938                          3              63                     15
# 939                          5              54                     28
# 940                         26              69                     16
# 941                         25              87                     10
# 942                          8              66                     34
# 943                          5              74                     30
# 944                         15              66                     47
# 945                          4              60                      9
# 946                         13              83                      4
# 947                          7              57                     17
# 948                         10              44                     25
#
#      NumTrades60Ever2DerogPubRec  NumTrades90Ever2DerogPubRec  \
# 0                              0                            0
# 1                              1                            1
# 2                              0                            0
# 3                              0                            0
# 4                              2                            0
# 5                              1                            0
# 6                              0                            0
# 7                              0                            0
# 8                             -9                           -9
# 9                              1                            0
# 10                             1                            1
# 11                             0                            0
# ..                           ...                          ...
# 937                            0                            0
# 938                            1                            0
# 939                            1                            1
# 940                            0                            0
# 941                            0                            0
# 942                           19                           19
# 943                            1                            1
# 944                            0                            0
# 945                            0                            0
# 946                            4                            4
# 947                            0                            0
# 948                            0                            0
#
#      PercentTradesNeverDelq  ...  PercentInstallTrades  \
# 0                       100  ...                    50
# 1                       100  ...                    17
# 2                        88  ...                    41
# 3                       100  ...                    27
# 4                        72  ...                    22
# 5                        94  ...                    53
# 6                       100  ...                    25
# 7                        95  ...                    39
# 8                        -9  ...                    -9
# 9                        89  ...                    36
# 10                       79  ...                    64
# 11                      100  ...                    58
# ..                      ...  ...                   ...
# 937                     100  ...                    14
# 938                      81  ...                    50
# 939                      90  ...                    58
# 940                     100  ...                    38
# 941                     100  ...                    50
# 942                      94  ...                    34
# 943                      90  ...                    57
# 944                     100  ...                    21
# 945                     100  ...                    44
# 946                      67  ...                    33
# 947                     100  ...                    24
# 948                      92  ...                    16
#
#     MSinceMostRecentInqexcl7days NumInqLast6M  NumInqLast6Mexcl7days  \
# 0                              0            0                      0
# 1                              0            1                      1
# 2                              0            0                      0
# 3                              0            0                      0
# 4                              1            3                      3
# 5                             -7            3                      3
# 6                              0            0                      0
# 7                              5            0                      0
# 8                             -9           -9                     -9
# 9                              0            7                      7
# 10                             0            1                      1
# 11                            -8            0                      0
# ..                           ...          ...                    ...
# 937                            5            1                      1
# 938                            0            4                      4
# 939                            0            0                      0
# 940                            0            1                      1
# 941                            0            2                      2
# 942                           -7            0                      0
# 943                            0            5                      4
# 944                            0            4                      4
# 945                            0            1                      1
# 946                           -7            0                      0
# 947                           -7            0                      0
# 948                            9            0                      0
#
#      NetFractionRevolvingBurden  NetFractionInstallBurden  \
# 0                            38                        91
# 1                             8                        -8
# 2                            40                        56
# 3                            90                        90
# 4                            48                        61
# 5                            44                        81
# 6                             0                        52
# 7                            32                        48
# 8                            -9                        -9
# 9                            39                        60
# 10                           48                        19
# 11                           19                        55
# ..                          ...                       ...
# 937                           0                        50
# 938                          32                        66
# 939                          51                        62
# 940                           4                        43
# 941                          10                        -8
# 942                          14                        68
# 943                          64                        75
# 944                           9                        82
# 945                          60                        95
# 946                          67                        -8
# 947                          19                        85
# 948                          41                        74
#
#      NumRevolvingTradesWBalance  NumInstallTradesWBalance  \
# 0                             2                         2
# 1                             2                         1
# 2                             2                         2
# 3                             8                         4
# 4                             4                         2
# 5                             5                         9
# 6                             0                         2
# 7                             6                         4
# 8                            -9                        -9
# 9                             5                         4
# 10                            5                         4
# 11                            2                         6
# ..                          ...                       ...
# 937                           4                         2
# 938                           3                         4
# 939                           4                         5
# 940                           2                         2
# 941                           2                        -8
# 942                           4                         6
# 943                           6                         4
# 944                           5                         6
# 945                           2                         2
# 946                           2                         1
# 947                           3                         3
# 948                          10                         3
#
#      NumBank2NatlTradesWHighUtilization  PercentTradesWBalance
# 0                                     0                     80
# 1                                     0                     75
# 2                                     0                    100
# 3                                     4                     86
# 4                                     1                     67
# 5                                     0                    100
# 6                                     0                     25
# 7                                     2                     57
# 8                                    -9                     -9
# 9                                     1                     64
# 10                                    0                    100
# 11                                    0                     80
# ..                                  ...                    ...
# 937                                   0                     46
# 938                                   0                     64
# 939                                   1                     75
# 940                                   0                     40
# 941                                   0                     67
# 942                                   0                     77
# 943                                   2                     92
# 944                                   1                     58
# 945                                   0                     80
# 946                                   0                    100
# 947                                   0                     60
# 948                                   2                     65
#
# [949 rows x 25 columns]

# %%
# Print table with descriptive statistics for all the continuous features
ctDataCleaned.select_dtypes(['float64', 'int64']).describe().T
# Out:
#                                     count        mean         std  min    25%  \
# Unnamed: 0                          949.0  498.696523  290.545759  0.0  246.0
# ExternalRiskEstimate                949.0   71.800843   10.362591 -9.0   65.0
# MSinceOldestTradeOpen               949.0  194.305585   99.624429 -9.0  130.0
# MSinceMostRecentTradeOpen           949.0    9.374078   11.781243 -9.0    3.0
# AverageMInFile                      949.0   77.778714   32.664086 -9.0   58.0
# NumSatisfactoryTrades               949.0   20.581665   11.178024 -9.0   12.0
# NumTrades60Ever2DerogPubRec         949.0    0.679663    1.733456 -9.0    0.0
# NumTrades90Ever2DerogPubRec         949.0    0.453109    1.527236 -9.0    0.0
# PercentTradesNeverDelq              949.0   91.970495   12.489285 -9.0   88.0
# MSinceMostRecentDelq                949.0    7.759747   20.299062 -9.0   -7.0
# NumTotalTrades                      949.0   21.626976   12.232796 -9.0   13.0
# NumTradesOpeninLast12M              949.0    1.891465    1.943240 -9.0    0.0
# PercentInstallTrades                949.0   35.463646   17.344852 -9.0   23.0
# MSinceMostRecentInqexcl7days        949.0    0.142255    5.742340 -9.0    0.0
# NumInqLast6M                        949.0    1.420443    2.017655 -9.0    0.0
# NumInqLast6Mexcl7days               949.0    1.353003    1.978456 -9.0    0.0
# NetFractionRevolvingBurden          949.0   34.987355   29.802866 -9.0    8.0
# NetFractionInstallBurden            949.0   41.799789   42.105152 -9.0   -8.0
# NumRevolvingTradesWBalance          949.0    3.732350    3.306115 -9.0    2.0
# NumInstallTradesWBalance            949.0    1.604847    3.374766 -9.0    1.0
# NumBank2NatlTradesWHighUtilization  949.0    0.513172    2.674912 -9.0    0.0
# PercentTradesWBalance               949.0   66.678609   22.880237 -9.0   50.0
#
#                                       50%    75%    max
# Unnamed: 0                          501.0  750.0  999.0
# ExternalRiskEstimate                 72.0   80.0   93.0
# MSinceOldestTradeOpen               177.0  261.0  530.0
# MSinceMostRecentTradeOpen             6.0   11.0  156.0
# AverageMInFile                       75.0   95.0  257.0
# NumSatisfactoryTrades                19.0   27.0   65.0
# NumTrades60Ever2DerogPubRec           0.0    1.0   19.0
# NumTrades90Ever2DerogPubRec           0.0    0.0   19.0
# PercentTradesNeverDelq               97.0  100.0  100.0
# MSinceMostRecentDelq                  1.0   16.0   82.0
# NumTotalTrades                       20.0   29.0   68.0
# NumTradesOpeninLast12M                1.0    3.0   12.0
# PercentInstallTrades                 33.0   45.0  100.0
# MSinceMostRecentInqexcl7days          0.0    1.0   23.0
# NumInqLast6M                          1.0    2.0   21.0
# NumInqLast6Mexcl7days                 1.0    2.0   21.0
# NetFractionRevolvingBurden           31.0   57.0  165.0
# NetFractionInstallBurden             50.0   82.0  140.0
# NumRevolvingTradesWBalance            3.0    5.0   23.0
# NumInstallTradesWBalance              2.0    3.0   19.0
# NumBank2NatlTradesWHighUtilization    1.0    1.0   16.0
# PercentTradesWBalance                67.0   83.0  100.0

# %% [markdown]
# #### The minimum value column is still skewed since eliminating the duplicate values (since that would leave one row with the -9 value all the way across. We should drop this row in order to see what the minimum values are.
#
# #### After updating to remove the -9 rows below, we notice that more "special meaning values" are visible in the data. This includes -8 but not -7. It's important to note that these features are not intended to represent numerical values, but are coded with meanings. Therefore, if we are looking to analyse the numerical representation of these data, the data cannot be combined catergorical with continuous.
#
# #### These minus values do not represent what the feature is assessing (which is a count of how long it has been since the entry has experienced a delinquency, i.e. the scale should start from 0. Therefore, we don't want these features in the table to analyse statistics, however they should also be considered useful information since those rows carry special meaning and may provide alternative insights. This should be handled in the data quality plan.

# %%
# Print table with descriptive statistics for all the categorical features
ctDataCleaned.select_dtypes(['category']).describe().T
# Out:
#                          count unique  top freq
# RiskPerformance            900      2  Bad  473
# MaxDelq2PublicRecLast12M   900     10    7  382
# MaxDelqEver                900      8    8  408

# %% [markdown]
# #### Above, we notice that 49 values are missing from our Data Set, so we have decided to check for null values. As we can see below, null values are indeed 49 for the three features.

# %%
ctDataCleaned.isnull().sum()
# Out:
# Unnamed: 0                             0
# RiskPerformance                       49
# ExternalRiskEstimate                   0
# MSinceOldestTradeOpen                  0
# MSinceMostRecentTradeOpen              0
# AverageMInFile                         0
# NumSatisfactoryTrades                  0
# NumTrades60Ever2DerogPubRec            0
# NumTrades90Ever2DerogPubRec            0
# PercentTradesNeverDelq                 0
# MSinceMostRecentDelq                   0
# MaxDelq2PublicRecLast12M              49
# MaxDelqEver                           49
# NumTotalTrades                         0
# NumTradesOpeninLast12M                 0
# PercentInstallTrades                   0
# MSinceMostRecentInqexcl7days           0
# NumInqLast6M                           0
# NumInqLast6Mexcl7days                  0
# NetFractionRevolvingBurden             0
# NetFractionInstallBurden               0
# NumRevolvingTradesWBalance             0
# NumInstallTradesWBalance               0
# NumBank2NatlTradesWHighUtilization     0
# PercentTradesWBalance                  0
# dtype: int64

# %%
# Identifying the rows with null data for further investigation
# According to Kelleher, Namee and D'arcy (2015), any target feature with missing values should have that instance
# removed (i.e. complete case analysis). This makes sense since, prior to training our model, we need valid data
# for our machine learning model to learn from. Filling in this data does not seem wise.

null_data = ctDataCleaned[ctDataCleaned.isnull().any(axis=1)]
null_data
# Out:
#      Unnamed: 0 RiskPerformance  ExternalRiskEstimate  MSinceOldestTradeOpen  \
# 62           63             NaN                    83                    363
# 102         104             NaN                    66                    311
# 126         129             NaN                    72                    391
# 150         154             NaN                    84                    347
# 156         161             NaN                    82                    100
# 186         193             NaN                    73                     44
# 190         197             NaN                    80                    158
# 230         238             NaN                    78                    263
# 242         252             NaN                    76                    432
# 249         259             NaN                    63                    134
# 281         294             NaN                    59                    370
# 284         297             NaN                    84                     98
# ..          ...             ...                   ...                    ...
# 737         779             NaN                    81                     98
# 741         783             NaN                    83                    306
# 753         795             NaN                    81                    166
# 765         807             NaN                    72                    354
# 767         809             NaN                    64                    164
# 814         859             NaN                    76                    400
# 816         861             NaN                    71                    117
# 843         889             NaN                    74                     -8
# 878         927             NaN                    76                    130
# 893         942             NaN                    88                    367
# 903         952             NaN                    58                    265
# 904         953             NaN                    69                    155
#
#      MSinceMostRecentTradeOpen  AverageMInFile  NumSatisfactoryTrades  \
# 62                          27             127                     20
# 102                          9              84                     32
# 126                         14              95                     15
# 150                          5              75                     25
# 156                          3              37                      9
# 186                          7              32                     10
# 190                          7              58                     25
# 230                         23             102                     19
# 242                         14             115                     24
# 249                          5              81                     17
# 281                         11              96                     10
# 284                         35              68                      7
# ..                         ...             ...                    ...
# 737                          3              40                     22
# 741                         27             113                     17
# 753                          4              60                     20
# 765                          4             105                     22
# 767                          8              71                     25
# 814                          3              97                     17
# 816                          4              37                     13
# 843                          2              59                     24
# 878                          2              72                     13
# 893                         25             170                     26
# 903                          3              79                     25
# 904                          3              52                     31
#
#      NumTrades60Ever2DerogPubRec  NumTrades90Ever2DerogPubRec  \
# 62                             0                            0
# 102                            1                            1
# 126                            0                            0
# 150                            0                            0
# 156                            0                            0
# 186                            0                            0
# 190                            0                            0
# 230                            0                            0
# 242                            0                            0
# 249                            1                            0
# 281                            2                            2
# 284                            0                            0
# ..                           ...                          ...
# 737                            0                            0
# 741                            0                            0
# 753                            0                            0
# 765                            0                            0
# 767                            1                            0
# 814                            1                            1
# 816                            0                            0
# 843                            0                            0
# 878                            0                            0
# 893                            0                            0
# 903                            2                            1
# 904                            0                            0
#
#      PercentTradesNeverDelq  ...  PercentInstallTrades  \
# 62                       85  ...                    40
# 102                     100  ...                    39
# 126                      87  ...                    27
# 150                     100  ...                    44
# 156                     100  ...                    22
# 186                     100  ...                    30
# 190                     100  ...                    19
# 230                      95  ...                    42
# 242                      96  ...                    21
# 249                      70  ...                    45
# 281                      75  ...                    50
# 284                     100  ...                    29
# ..                      ...  ...                   ...
# 737                     100  ...                    17
# 741                     100  ...                    65
# 753                     100  ...                    20
# 765                     100  ...                    29
# 767                      92  ...                    38
# 814                      94  ...                    18
# 816                     100  ...                   100
# 843                      82  ...                    29
# 878                      93  ...                    43
# 893                     100  ...                    19
# 903                      93  ...                    48
# 904                     100  ...                    29
#
#     MSinceMostRecentInqexcl7days NumInqLast6M  NumInqLast6Mexcl7days  \
# 62                            -8            0                      0
# 102                           -7            0                      0
# 126                           -8            0                      0
# 150                            4            1                      1
# 156                           -7            1                      1
# 186                            8            0                      0
# 190                           13            0                      0
# 230                           14            0                      0
# 242                            0            4                      4
# 249                            7            0                      0
# 281                           -7            1                      1
# 284                           -8            0                      0
# ..                           ...          ...                    ...
# 737                            1            4                      3
# 741                           -8            0                      0
# 753                            5            1                      1
# 765                            0            0                      0
# 767                            0            3                      3
# 814                            2            1                      1
# 816                            2            1                      1
# 843                           -7            3                      3
# 878                           -7            0                      0
# 893                            0            0                      0
# 903                            0            1                      1
# 904                           -7            2                      2
#
#      NetFractionRevolvingBurden  NetFractionInstallBurden  \
# 62                            0                        -8
# 102                          48                        64
# 126                          30                        72
# 150                           2                        81
# 156                           0                        99
# 186                          55                        -8
# 190                          19                        80
# 230                          17                        29
# 242                          13                        -8
# 249                          80                        34
# 281                          76                        -8
# 284                          12                        -8
# ..                          ...                       ...
# 737                           0                        81
# 741                          43                        33
# 753                           0                         3
# 765                          89                        77
# 767                          58                        84
# 814                           2                        96
# 816                          -8                        72
# 843                          12                        91
# 878                          21                        -8
# 893                           1                        39
# 903                          63                        50
# 904                          51                        98
#
#      NumRevolvingTradesWBalance  NumInstallTradesWBalance  \
# 62                            1                         2
# 102                           9                         5
# 126                           8                         2
# 150                           2                         3
# 156                           3                         1
# 186                           3                         1
# 190                           2                         2
# 230                           6                         3
# 242                           7                         2
# 249                           4                         2
# 281                           2                         1
# 284                           2                         1
# ..                          ...                       ...
# 737                           0                         1
# 741                           3                         2
# 753                           1                         3
# 765                           7                         3
# 767                           3                         3
# 814                           4                         2
# 816                          -8                         5
# 843                           3                         1
# 878                           2                         1
# 893                           1                         1
# 903                           8                         2
# 904                           3                         3
#
#      NumBank2NatlTradesWHighUtilization  PercentTradesWBalance
# 62                                    0                     57
# 102                                   1                     74
# 126                                   1                     91
# 150                                   0                     56
# 156                                   0                     67
# 186                                   0                     67
# 190                                   1                     50
# 230                                   0                     82
# 242                                   0                     63
# 249                                   3                    100
# 281                                   1                    100
# 284                                   0                     75
# ..                                  ...                    ...
# 737                                   0                     11
# 741                                   0                     83
# 753                                   0                     25
# 765                                   5                     92
# 767                                   0                     67
# 814                                   0                     75
# 816                                  -8                    100
# 843                                   0                     40
# 878                                   0                     60
# 893                                   0                     25
# 903                                   0                     91
# 904                                   2                     46
#
# [49 rows x 25 columns]

# %% [markdown]
# ## Plotting the data

# %%
# Plot a histogram for all continuous features
cleanedContinuousCols = ["ExternalRiskEstimate",\
                  "PercentTradesNeverDelq",\
                  "PercentInstallTrades",\
                  "MSinceMostRecentInqexcl7days",\
                  "NetFractionRevolvingBurden",\
                  "NetFractionInstallBurden",\
                  "NumRevolvingTradesWBalance",\
                  "NumInstallTradesWBalance",\
                  "NumBank2NatlTradesWHighUtilization",\
                  "PercentTradesWBalance",\
                  "MSinceOldestTradeOpen",\
                  "MSinceMostRecentTradeOpen",\
                  "AverageMInFile",\
                  "NumSatisfactoryTrades",\
                  "NumTrades60Ever2DerogPubRec",\
                  "NumTrades90Ever2DerogPubRec",\
                  "MSinceMostRecentDelq",\
                  "NumTotalTrades",\
                  "NumTradesOpeninLast12M",\
                  "NumInqLast6Mexcl7days"]

ctDataCleaned[cleanedContinuousCols].hist(figsize=(30,30))
plt.savefig('continuous_histograms_1-1.pdf')

# %%
# Plot box plots for all the continuous features and save in a PDF file
pp = PdfPages('continuous_boxplots_1-1.pdf')

for col in cleanedContinuousCols:
    f = ctDataCleaned[col].plot(kind='box', figsize=(8,5))
    pp.savefig(f.get_figure())
    plt.show()

pp.close()

# %%
# Plot bar charts for all categorical features and save them in a single PDF file
pp = PdfPages('categorical_barcharts_1-1.pdf')

for column in ctCategorical:
    f = ctDataCleaned[column].value_counts().plot(kind='bar', title=column, figsize=(7,5))
    pp.savefig(f.get_figure())
    plt.show()

pp.close()

# %%
# Calculating the median will be useful for comparing our mean and median descriptive statistics. 
# It can point out the presence of signficant outliers.
ctDataCleaned.median()
# Out:
# Unnamed: 0                            501.0
# ExternalRiskEstimate                   72.0
# MSinceOldestTradeOpen                 177.0
# MSinceMostRecentTradeOpen               6.0
# AverageMInFile                         75.0
# NumSatisfactoryTrades                  19.0
# NumTrades60Ever2DerogPubRec             0.0
# NumTrades90Ever2DerogPubRec             0.0
# PercentTradesNeverDelq                 97.0
# MSinceMostRecentDelq                    1.0
# MaxDelq2PublicRecLast12M                6.0
# MaxDelqEver                             6.0
# NumTotalTrades                         20.0
# NumTradesOpeninLast12M                  1.0
# PercentInstallTrades                   33.0
# MSinceMostRecentInqexcl7days            0.0
# NumInqLast6M                            1.0
# NumInqLast6Mexcl7days                   1.0
# NetFractionRevolvingBurden             31.0
# NetFractionInstallBurden               50.0
# NumRevolvingTradesWBalance              3.0
# NumInstallTradesWBalance                2.0
# NumBank2NatlTradesWHighUtilization      1.0
# PercentTradesWBalance                  67.0
# dtype: float64

# %% [markdown]
# ### Investigating whether PercentTradesNeverDelq is valid, since a high number of accounts rated with no delinquencies are still rated with "bad" risk performance.

# %%
# Total data in frame at this point
ctDataCleaned.shape
# Out:
# (949, 25)

# %%
# Many of these features are also having listed as "been delinquent" in the last 12 months or having a 
# delinquency ever are simultaneously listed as having their percentage of trades that were never delinquent as 100.
ctDataCleaned.loc[(ctDataCleaned['PercentTradesNeverDelq'] == 100) &\
                  (ctDataCleaned['MaxDelqEver'] != 8)].shape
# Out:
# (240, 25)

# %%
# Percentage of accounts that have never been delinquent but also rated as "bad"
# The total figure is adopted from below (section 2), as we have removed rows from the total dataframe, but the number
# above stayed the same.

percentRatedBad = 240/898 * 100
print(percentRatedBad)
# Out:
# 26.7260579064588

# %%
print("Percentage of trades simultaneously rated as never delinquent but also having been recorded as having\
 a delinquency at some point previously or delinquency is unknown:", percentRatedBad)
# Out:
# Percentage of trades simultaneously rated as never delinquent but also having been recorded as having a delinquency at some point previously or delinquency is unknown: 26.7260579064588

# %% [markdown]
# ### Investiagting whether NetFractionInstallBurden is missing a high percentage of values (-8 special meaning)

# %%
# Number of missing/unknown fields in this feature
ctDataCleaned.loc[(ctDataCleaned['NetFractionInstallBurden'] == -8)].shape
# Out:
# (334, 25)

# %%
# Percentage of total
# The total figure is adopted from below (section 2), as we have removed rows from the total dataframe, but the number
# above stayed the same.
NetFracInstallBurdPercentage = 334/898 * 100
print(NetFracInstallBurdPercentage)
# Out:
# 37.193763919821826

# %% [markdown]
# # 2. Data Quality Plan -- Actions

# %% [markdown]
# ### Actions to be carried out per Quality Plan document:
# -  Remove NaN instances for our target feature RiskPerformance
# -  Make -7 = NaN in MSinceMostRecentDelq and MSinceMostRecenetInqexcl7days so it doesn't skew our statistical analysis. Additionally, it would allow us to correlate features between those who do have a value and those who don't at a later stage.
# -  Drop the remaining two rows that have -9 special meaning values, since they don't appear to have any useful information in the instance.
# -  Set -8 = NaN in NetFractionInstallBurden for the same reason as MSinceMostRecentDelq and MSinceMostRecenetInqexcl7days.
# -  Replace -8 special values with mean where they occur in each column with a low percentage of incidence for this value. Each of these instances has information we would not like to lose, and -8 doesn't occur enough to warrant dropping any of the features.
# -  Replace PercentTradesNeverDelq == 100 with NaN where MaxDelqEver != 8 (special meaning - current and never delinquent) since this is obviously erroneous.

# %% [markdown]
# #### We are going to drop the instances where RiskPerformance is NaN, as this is a target feature.

# %%
ctDataCleaned.dropna(subset=['RiskPerformance'], inplace=True)

# %%
# Test if dropping the NaN columns worked.
null_data = ctDataCleaned[ctDataCleaned.isnull().any(axis=1)]
null_data
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, RiskPerformance, ExternalRiskEstimate, MSinceOldestTradeOpen, MSinceMostRecentTradeOpen, AverageMInFile, NumSatisfactoryTrades, NumTrades60Ever2DerogPubRec, NumTrades90Ever2DerogPubRec, PercentTradesNeverDelq, MSinceMostRecentDelq, MaxDelq2PublicRecLast12M, MaxDelqEver, NumTotalTrades, NumTradesOpeninLast12M, PercentInstallTrades, MSinceMostRecentInqexcl7days, NumInqLast6M, NumInqLast6Mexcl7days, NetFractionRevolvingBurden, NetFractionInstallBurden, NumRevolvingTradesWBalance, NumInstallTradesWBalance, NumBank2NatlTradesWHighUtilization, PercentTradesWBalance]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# #### Make -7 in MSinceMostRecentDelq and MSinceMOstRecentInqExcl7days == NaN so later we can correlate features with a value or without a value (effectively acting as a boolean).

# %%
ctDataCleaned["MSinceMostRecentInqexcl7days"].replace(-7, np.nan,inplace=True)
ctDataCleaned["MSinceMostRecentDelq"].replace(-7, np.nan,inplace=True)

# %% [markdown]
# #### Drop rows with all -9 values

# %%
# Single line not solid enough, as a single -9 might be present an useful.
#ctDataCleaned.drop(ctDataCleaned[ctDataCleaned.MSinceMostRecentDelq == -9].index, inplace=True)

# Specify the drop on multiple conditions to ensure only rows that are -9 across will be dropped.
ctDataCleaned.drop(ctDataCleaned[(ctDataCleaned['MSinceMostRecentDelq'] == -9) &\
                                 (ctDataCleaned['ExternalRiskEstimate'] == -9) &\
                                 (ctDataCleaned['MSinceOldestTradeOpen'] == -9) &\
                                 (ctDataCleaned['MSinceMostRecentTradeOpen'] == -9) &\
                                 (ctDataCleaned['AverageMInFile'] == -9) &\
                                 (ctDataCleaned['NumTotalTrades'] == -9) &\
                                 (ctDataCleaned['NumInqLast6M'] == -9) &\
                                 (ctDataCleaned['NetFractionRevolvingBurden'] == -9)].index, inplace=True)

# %%
# test to make sure they're dropped
ctDataCleaned[ctDataCleaned.MSinceMostRecentDelq == -9]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, RiskPerformance, ExternalRiskEstimate, MSinceOldestTradeOpen, MSinceMostRecentTradeOpen, AverageMInFile, NumSatisfactoryTrades, NumTrades60Ever2DerogPubRec, NumTrades90Ever2DerogPubRec, PercentTradesNeverDelq, MSinceMostRecentDelq, MaxDelq2PublicRecLast12M, MaxDelqEver, NumTotalTrades, NumTradesOpeninLast12M, PercentInstallTrades, MSinceMostRecentInqexcl7days, NumInqLast6M, NumInqLast6Mexcl7days, NetFractionRevolvingBurden, NetFractionInstallBurden, NumRevolvingTradesWBalance, NumInstallTradesWBalance, NumBank2NatlTradesWHighUtilization, PercentTradesWBalance]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# #### Set -8 in NetFractionInstallBurden and MSinceMostRecentInqexcl7days == NaN as a flag indicator. Will allow us to continue using remaining data with values in further statistical analysis and feature correlation.

# %%
ctDataCleaned["NetFractionInstallBurden"].replace(-8, np.nan,inplace=True)
ctDataCleaned["MSinceMostRecentInqexcl7days"].replace(-8, np.nan,inplace=True)

# %%
# test for null values
print(ctDataCleaned["NetFractionInstallBurden"].isnull().sum())
print(ctDataCleaned["MSinceMostRecentInqexcl7days"].isnull().sum())
# Out:
# 321
# 209

# %% [markdown]
# #### Turn -8 values into mean in respective columns

# %%
# Exclude MSinceMostRecentDelq, MSinceMostRecentInqexcl7days and NetFractionInstallBurden 
# since we want to deal with those separately and -8 doesn't appear in a high percentage
# in any of these other columns, so it's safe to impute the mean in each.

excluded = ["ExternalRiskEstimate",\
              "PercentTradesNeverDelq",\
              "PercentInstallTrades",\
              "NetFractionRevolvingBurden",\
              "NumRevolvingTradesWBalance",\
              "NumInstallTradesWBalance",\
              "NumBank2NatlTradesWHighUtilization",\
              "PercentTradesWBalance",\
              "MSinceOldestTradeOpen",\
              "MSinceMostRecentTradeOpen",\
              "AverageMInFile",\
              "NumSatisfactoryTrades",\
              "NumTrades60Ever2DerogPubRec",\
              "NumTrades90Ever2DerogPubRec",\
              "NumTotalTrades",\
              "NumTradesOpeninLast12M",\
              "NumInqLast6Mexcl7days"]

# First set -8 to NaN
for i in excluded:
    ctDataCleaned[i].replace(-8, np.nan,inplace=True)

#Next fill NaN values with the mean of the respective column
for i in excluded:
    ctDataCleaned[i].fillna((ctDataCleaned[i].mean()), inplace=True)

# Manually replace -8s in MSinceMostRecentDelq since we have many NaN values that we want to keep as NaN as flags 
# and not confuse them with missing data.
ctDataCleaned['MSinceMostRecentDelq'].replace(-8,ctDataCleaned['MSinceMostRecentDelq'].mean(),inplace=True)

# %%
# test to make sure they've been updated
ctDataCleaned[ctDataCleaned.MSinceMostRecentDelq == -8]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, RiskPerformance, ExternalRiskEstimate, MSinceOldestTradeOpen, MSinceMostRecentTradeOpen, AverageMInFile, NumSatisfactoryTrades, NumTrades60Ever2DerogPubRec, NumTrades90Ever2DerogPubRec, PercentTradesNeverDelq, MSinceMostRecentDelq, MaxDelq2PublicRecLast12M, MaxDelqEver, NumTotalTrades, NumTradesOpeninLast12M, PercentInstallTrades, MSinceMostRecentInqexcl7days, NumInqLast6M, NumInqLast6Mexcl7days, NetFractionRevolvingBurden, NetFractionInstallBurden, NumRevolvingTradesWBalance, NumInstallTradesWBalance, NumBank2NatlTradesWHighUtilization, PercentTradesWBalance]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# #### Replace PercentTradesNeverDelq == 100 with NaN where MaxDelqEver != 8 (special meaning - current and never delinquent) since this is obviously erroneous.

# %%
# First check if we have missing values
ctDataCleaned['PercentTradesNeverDelq'].isnull().sum()
# Out:
# 0

# %%
# check for trades that have been delinquent versus the percentage of accounts listed as having 100% no
# delinquency. Since this it is impossible to be listed as having "PercentTradesNeverDelq=100" and simultaneously
# not having a value of 8 for "MaxDelqEver", this feature needs to be rectified.
ctDataCleaned.loc[(ctDataCleaned["PercentTradesNeverDelq"] == 100) & (ctDataCleaned["MaxDelqEver"] != 8),"PercentTradesNeverDelq"].count()
# Out:
# 214

# %%
# Convert all values where 100 appears but MaxDelqEver is not 8 or 1 (special meaning values)
# and set it to NaN to signify missing values. These data were considered erroneous, as you cannot have
# 100% never had delinquency while simultaneously having been recorded as having a delinquency.

ctDataCleaned.loc[(ctDataCleaned["PercentTradesNeverDelq"] == 100) & (ctDataCleaned["MaxDelqEver"] != 8), "PercentTradesNeverDelq"]\
                    = np.nan

ctDataCleaned.loc[(ctDataCleaned["PercentTradesNeverDelq"] == 100) & (ctDataCleaned["MaxDelqEver"] != 8), "PercentTradesNeverDelq"]
# Out:
# Series([], Name: PercentTradesNeverDelq, dtype: float64)

# %%
# Check to see if it worked
ctDataCleaned['PercentTradesNeverDelq'].isnull().sum()
# Out:
# 214

# %%
ctDataCleaned.to_csv('finalCreditRisk-18206645.csv')

# %% [markdown]
# ## Re-do statistics tables for continuous and categorical features

# %%
# continuous features
ctDataCleaned.select_dtypes(['float64', 'int64']).describe().T
# Out:
#                                     count        mean         std   min  \
# Unnamed: 0                          898.0  498.511136  291.814163   0.0
# ExternalRiskEstimate                898.0   71.922049    9.705045  40.0
# MSinceOldestTradeOpen               898.0  199.157714   93.069484  23.0
# MSinceMostRecentTradeOpen           898.0    9.497773   11.938457   0.0
# AverageMInFile                      898.0   77.979955   32.744401   9.0
# NumSatisfactoryTrades               898.0   20.582405   11.160649   1.0
# NumTrades60Ever2DerogPubRec         898.0    0.723831    1.714100   0.0
# NumTrades90Ever2DerogPubRec         898.0    0.489978    1.499316   0.0
# PercentTradesNeverDelq              684.0   89.611111   12.451167  27.0
# MSinceMostRecentDelq                481.0   21.536102   19.960770   0.0
# NumTotalTrades                      898.0   21.717149   12.302403   0.0
# NumTradesOpeninLast12M              898.0    1.914254    1.890656   0.0
# PercentInstallTrades                898.0   35.631403   17.242613   0.0
# MSinceMostRecentInqexcl7days        689.0    2.399129    4.617528   0.0
# NumInqLast6M                        898.0    1.456570    1.966499   0.0
# NumInqLast6Mexcl7days               898.0    1.390869    1.937083   0.0
# NetFractionRevolvingBurden          898.0   35.832579   29.402319   0.0
# NetFractionInstallBurden            577.0   69.183709   25.083836   2.0
# NumRevolvingTradesWBalance          898.0    3.913093    2.939052   0.0
# NumInstallTradesWBalance            898.0    2.544567    1.600976   1.0
# NumBank2NatlTradesWHighUtilization  898.0    1.086698    1.509048   0.0
# PercentTradesWBalance               898.0   66.872910   22.566920   0.0
#
#                                        25%    50%         75%    max
# Unnamed: 0                          243.25  502.5  750.750000  999.0
# ExternalRiskEstimate                 65.00   72.0   79.750000   93.0
# MSinceOldestTradeOpen               135.25  185.0  261.000000  530.0
# MSinceMostRecentTradeOpen             3.00    6.0   12.000000  156.0
# AverageMInFile                       57.00   75.0   95.000000  257.0
# NumSatisfactoryTrades                12.00   19.0   27.000000   63.0
# NumTrades60Ever2DerogPubRec           0.00    0.0    1.000000   19.0
# NumTrades90Ever2DerogPubRec           0.00    0.0    0.000000   19.0
# PercentTradesNeverDelq               86.00   94.0  100.000000  100.0
# MSinceMostRecentDelq                  5.00   16.0   31.000000   82.0
# NumTotalTrades                       13.00   20.0   29.000000   68.0
# NumTradesOpeninLast12M                0.00    1.0    3.000000   12.0
# PercentInstallTrades                 24.00   33.0   46.000000  100.0
# MSinceMostRecentInqexcl7days          0.00    0.0    3.000000   23.0
# NumInqLast6M                          0.00    1.0    2.000000   21.0
# NumInqLast6Mexcl7days                 0.00    1.0    2.000000   21.0
# NetFractionRevolvingBurden            9.00   32.0   57.000000  165.0
# NetFractionInstallBurden             54.00   75.0   88.000000  140.0
# NumRevolvingTradesWBalance            2.00    3.0    5.000000   23.0
# NumInstallTradesWBalance              2.00    2.0    3.000000   19.0
# NumBank2NatlTradesWHighUtilization    0.00    1.0    1.086698   16.0
# PercentTradesWBalance                50.00   67.0   83.000000  100.0

# %%
# Print table with descriptive statistics for all the categorical features
ctDataCleaned.select_dtypes(['category']).describe().T
# Out:
#                          count unique  top freq
# RiskPerformance            898      2  Bad  472
# MaxDelq2PublicRecLast12M   898      9    7  382
# MaxDelqEver                898      7    8  408

# %% [markdown]
# ### Plot them one more time just for a final review

# %%
ctDataCleaned[cleanedContinuousCols].hist(figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002021C0BAA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021BA72C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021BEE5CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021E647F60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002021D564208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021D5A83C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021D584630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021C0148D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002021C014908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021D3AFD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021D3A7FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021BF83278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002021C0514E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021C2B4748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021C2DA9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021E659C18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002021C396E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021C34F128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021C270390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002021C2635F8>]],
#       dtype=object)

# %%
for col in cleanedContinuousCols:
    f = ctDataCleaned[col].plot(kind='box', figsize=(8,5))
    plt.show()

# %% [markdown]
# # 3. Exploring relationships between feature pairs

# %%
ctDataCleaned.columns.get_loc
# Out:
# <bound method Index.get_loc of Index(['Unnamed: 0', 'RiskPerformance', 'ExternalRiskEstimate',
#        'MSinceOldestTradeOpen', 'MSinceMostRecentTradeOpen', 'AverageMInFile',
#        'NumSatisfactoryTrades', 'NumTrades60Ever2DerogPubRec',
#        'NumTrades90Ever2DerogPubRec', 'PercentTradesNeverDelq',
#        'MSinceMostRecentDelq', 'MaxDelq2PublicRecLast12M', 'MaxDelqEver',
#        'NumTotalTrades', 'NumTradesOpeninLast12M', 'PercentInstallTrades',
#        'MSinceMostRecentInqexcl7days', 'NumInqLast6M', 'NumInqLast6Mexcl7days',
#        'NetFractionRevolvingBurden', 'NetFractionInstallBurden',
#        'NumRevolvingTradesWBalance', 'NumInstallTradesWBalance',
#        'NumBank2NatlTradesWHighUtilization', 'PercentTradesWBalance'],
#       dtype='object')>

# %%
ctDataCleaned.columns.get_loc('PercentTradesNeverDelq')
# Out:
# 9

# %%
# for i in cleanedContinuousCols:
#     ctDataCleaned.plot.scatter('RiskPerformance',i);
ctDataCleaned.plot.scatter(x='MSinceMostRecentTradeOpen', y='NetFractionRevolvingBurden');

# %%
copyDataFrame = ctDataCleaned
colsBackToInt = cleanedContinuousCols
for i in colsBackToInt:
    copyDataFrame[i] = copyDataFrame[i].astype("int64",copy=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-5c835a952c1b> in <module>
#       2 colsBackToInt = cleanedContinuousCols
#       3 for i in colsBackToInt:
# ----> 4     copyDataFrame[i] = copyDataFrame[i].astype("int64",copy=False)
#
# ~\Anaconda3\envs\dataAnalytics\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\Anaconda3\envs\dataAnalytics\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ~\Anaconda3\envs\dataAnalytics\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~\Anaconda3\envs\dataAnalytics\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~\Anaconda3\envs\dataAnalytics\lib\site-packages\pandas\core\internals\blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# ~\Anaconda3\envs\dataAnalytics\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     674
#     675         if not np.isfinite(arr).all():
# --> 676             raise ValueError('Cannot convert non-finite values (NA or inf) to '
#     677                              'integer')
#     678
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
copyDataFrame.dtypes
# Out:
# Unnamed: 0                               int64
# RiskPerformance                       category
# ExternalRiskEstimate                     int64
# MSinceOldestTradeOpen                  float64
# MSinceMostRecentTradeOpen                int64
# AverageMInFile                           int64
# NumSatisfactoryTrades                    int64
# NumTrades60Ever2DerogPubRec              int64
# NumTrades90Ever2DerogPubRec              int64
# PercentTradesNeverDelq                 float64
# MSinceMostRecentDelq                   float64
# MaxDelq2PublicRecLast12M              category
# MaxDelqEver                           category
# NumTotalTrades                           int64
# NumTradesOpeninLast12M                   int64
# PercentInstallTrades                     int64
# MSinceMostRecentInqexcl7days           float64
# NumInqLast6M                             int64
# NumInqLast6Mexcl7days                    int64
# NetFractionRevolvingBurden             float64
# NetFractionInstallBurden               float64
# NumRevolvingTradesWBalance             float64
# NumInstallTradesWBalance               float64
# NumBank2NatlTradesWHighUtilization     float64
# PercentTradesWBalance                  float64
# dtype: object
